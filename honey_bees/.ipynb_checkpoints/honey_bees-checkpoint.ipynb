# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#to import images
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

import matplotlib.pyplot as plt

# %%
directory = "bee_imgs/"
#64x64 for faster training.
#test
picture1 = image.load_img(directory+"041_066.png", target_size=(64,64))
picture1
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1C2558D588>

# %%
picture1_ = image.img_to_array(picture1)

# %%
picture1_.shape #3 channels, for 3 colors
# Out:
# (64, 64, 3)

# %%
df = pd.read_csv("bee_data.csv")

# %%
df.head()
# Out:
#           file     date   time        location  zip code subspecies  \
# 0  041_066.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 1  041_072.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 2  041_073.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 3  041_067.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 4  041_059.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
#
#               health  pollen_carrying   caste
# 0  hive being robbed            False  worker
# 1  hive being robbed            False  worker
# 2  hive being robbed            False  worker
# 3  hive being robbed            False  worker
# 4  hive being robbed            False  worker

# %%
X_ = [image.load_img(directory+img_name,target_size=(64,64)) for img_name in df["file"]]

# %%
#verified to be in order
X_[0]
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1C24A028D0>

# %%
#a list of np tensors in 
X = [np.array(image.img_to_array(i)) for i in X_]

# %%
print(np.amax(X))
print(np.amin(X))

#rescale for training
X = [i/255.0 for i in X]
print(np.amax(X))
print(np.amin(X))
# Out:
# 255.0
# 0.0
# 1.0
# 0.0

# %%
#let's put that in our dataframe since we dont have much data
df["img_array"] = X

# %%
df.head(5)
# Out:
#           file     date   time        location  zip code subspecies  \
# 0  041_066.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 1  041_072.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 2  041_073.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 3  041_067.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 4  041_059.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
#
#               health  pollen_carrying   caste  \
# 0  hive being robbed            False  worker
# 1  hive being robbed            False  worker
# 2  hive being robbed            False  worker
# 3  hive being robbed            False  worker
# 4  hive being robbed            False  worker
#
#                                            img_array
# 0  [[[0.84313726, 0.9411765, 0.6509804], [0.83921...
# 1  [[[0.9647059, 0.90588236, 0.827451], [0.964705...
# 2  [[[0.972549, 0.99215686, 0.8980392], [0.972549...
# 3  [[[0.90588236, 1.0, 0.7372549], [0.90588236, 1...
# 4  [[[0.9098039, 0.84313726, 0.7411765], [0.90980...

# %%
df.health.value_counts()
temp = []
for _ in df.health:
    if _ not in temp:
        temp.append(_)

# %%
temp
# Out:
# ['hive being robbed',
#  'healthy',
#  'few varrao, hive beetles',
#  'ant problems',
#  'missing queen',
#  'Varroa, Small Hive Beetles']

# %%
#recall, cnn only depends on 2 things, the target and the images themselves!
y_keys = {"healthy":np.array([1,0,0,0,0,0]),
         "few varrao, hive beetles":np.array([0,1,0,0,0,0]),
         "Varroa, Small Hive Beetles":np.array([0,0,1,0,0,0]),
         "ant problems":np.array([0,0,0,1,0,0]),
         "hive being robbed":np.array([0,0,0,0,1,0]),
         "missing queen":np.array([0,0,0,0,0,1])}
y = [y_keys[i] for i in df.health]

# %%
y
# Out:
# [array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([0, 0, 0, 0, 1, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([0, 1, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([1, 0, 0, 0, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  array([0, 0, 0, 1, 0, 0]),
#  ...]

# %% [markdown]
# # donc, on peut essayer de tester des inputs

# %%
#we'll be using keras for prototyping first
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras import callbacks

from sklearn.model_selection import train_test_split
history = callbacks.History() #need to be defined first

# %%
classifier = Sequential()

#classifier.add(Dense(units=6, init="glorot_uniform", activation="relu")) #3D array pixels for shape
#3x3 matrix with 32 feature maps in total, conventional. 3d array for colored img, RGB. 256 in term of intensity max/min
classifier.add(Convolution2D(5,3,3, input_shape=(64,64,3), activation="relu")) #tensorflow backend tuples = (128,128,3). Use relu to eliminate the neg values 
#maxpooling, normal pool_size is 2x2
classifier.add(MaxPooling2D(pool_size=(2,2),padding="SAME")) #took out strides=1 for speed (no overlapping! remember the paper)


#second convo layer to look for better accuracy. we don't need input shape, keras arleady knows that.
classifier.add(Convolution2D(32,3,3, activation="relu"))
classifier.add(MaxPooling2D(pool_size=(2,2),padding="SAME"))

#third convo layer with more feature filter size, 64 for better detection.
classifier.add(Convolution2D(64,3,3, activation="relu"))
classifier.add(MaxPooling2D(pool_size=(2,2))) #notice, no padding here



#Flattening to input the ann
classifier.add(Flatten()) #no argument needed

#Ann section with flattened stuff as input. Notice we don't need the input size like low level tensorflow here
#hidden layer, 500
classifier.add(Dense(500, activation="relu"))
#classifier.add(Dropout(0.01))
classifier.add(Dense(6, activation="softmax"))
# Out:
# /Library/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(5, (3, 3), input_shape=(64, 64, 3..., activation="relu")`
#   """
# /Library/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu")`
#   # This is added back by InteractiveShellApp.init_path()
# /Library/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
#   from ipykernel import kernelapp as app

# %%
#https://cwiki.apache.org/confluence/display/MXNET/Multi-hot+Sparse+Categorical+Cross-entropy
#we use categorical cross entropy for our sparse matrix target.
classifier.compile(optimizer="adam", loss="categorical_crossentropy",metrics=["accuracy"])

# %%
#after this, we should have: 30% test, 70%train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
#note that this val set isn't kfold
history = classifier.fit(np.array(X_train),np.array(y_train),validation_split=0.2, shuffle=True, epochs=50)
# Out:
# Train on 2896 samples, validate on 724 samples
# Epoch 1/50
# 2896/2896 [==============================] - 12s - loss: 1.0222 - acc: 0.6675 - val_loss: 0.7450 - val_acc: 0.7182
# Epoch 2/50
# 2896/2896 [==============================] - 9s - loss: 0.6297 - acc: 0.7738 - val_loss: 0.5560 - val_acc: 0.7790
# Epoch 3/50
# 2896/2896 [==============================] - 9s - loss: 0.4786 - acc: 0.8267 - val_loss: 0.4037 - val_acc: 0.8702
# Epoch 4/50
# 2896/2896 [==============================] - 9s - loss: 0.3577 - acc: 0.8650 - val_loss: 0.3363 - val_acc: 0.8577
# Epoch 5/50
# 2896/2896 [==============================] - 9s - loss: 0.2977 - acc: 0.8964 - val_loss: 0.3007 - val_acc: 0.8757
# Epoch 6/50
# 2896/2896 [==============================] - 9s - loss: 0.2341 - acc: 0.9164 - val_loss: 0.2612 - val_acc: 0.9061
# Epoch 7/50
# 2896/2896 [==============================] - 9s - loss: 0.2072 - acc: 0.9223 - val_loss: 0.2449 - val_acc: 0.9033
# Epoch 8/50
# 2896/2896 [==============================] - 9s - loss: 0.1535 - acc: 0.9382 - val_loss: 0.2732 - val_acc: 0.8964
# Epoch 9/50
# 2896/2896 [==============================] - 9s - loss: 0.1207 - acc: 0.9561 - val_loss: 0.2337 - val_acc: 0.9116
# Epoch 10/50
- loss: 0.0011 - acc: 1.0000 - val_loss: 0.2955 - val_acc: 0.9420
# Epoch 33/50
# 2896/2896 [==============================] - 9s - loss: 7.7371e-04 - acc: 1.0000 - val_loss: 0.3058 - val_acc: 0.9392
# Epoch 34/50
# 2896/2896 [==============================] - 9s - loss: 6.1434e-04 - acc: 1.0000 - val_loss: 0.3129 - val_acc: 0.9434
# Epoch 35/50
# 2896/2896 [==============================] - 9s - loss: 4.9734e-04 - acc: 1.0000 - val_loss: 0.3163 - val_acc: 0.9406
# Epoch 36/50
# 2896/2896 [==============================] - 9s - loss: 3.7757e-04 - acc: 1.0000 - val_loss: 0.3224 - val_acc: 0.9434
# Epoch 37/50
# 2896/2896 [==============================] - 9s - loss: 3.3557e-04 - acc: 1.0000 - val_loss: 0.3244 - val_acc: 0.9434
# Epoch 38/50
# 2896/2896 [==============================] - 9s - loss: 2.9433e-04 - acc: 1.0000 - val_loss: 0.3300 - val_acc: 0.9406
# Epoch 39/50
# 2896/2896 [==============================] - 9s - loss: 2.6454e-04 - acc: 1.0000 - val_loss: 0.3320 - val_acc: 0.9420
# Epoch 40/50
# 2896/2896 [==============================] - 9s - loss: 2.4606e-04 - acc: 1.0000 - val_loss: 0.3387 - val_acc: 0.9420
# Epoch 41/50
# 2896/2896 [==============================] - 9s - loss: 2.1126e-04 - acc: 1.0000 - val_loss: 0.3396 - val_acc: 0.9392
# Epoch 42/50
# 2896/2896 [==============================] - 9s - loss: 1.8946e-04 - acc: 1.0000 - val_loss: 0.3452 - val_acc: 0.9434
# Epoch 43/50
# 2896/2896 [==============================] - 9s - loss: 1.6974e-04 - acc: 1.0000 - val_loss: 0.3488 - val_acc: 0.9448
# Epoch 44/50
# 2896/2896 [==============================] - 9s - loss: 1.5467e-04 - acc: 1.0000 - val_loss: 0.3498 - val_acc: 0.9461
# Epoch 45/50
# 2896/2896 [==============================] - 9s - loss: 1.3874e-04 - acc: 1.0000 - val_loss: 0.3542 - val_acc: 0.9448
# Epoch 46/50
# 2896/2896 [==============================] - 10s - loss: 1.2990e-04 - acc: 1.0000 - val_loss: 0.3577 - val_acc: 0.9406
# Epoch 47/50
# 2896/2896 [==============================] - 9s - loss: 1.1413e-04 - acc: 1.0000 - val_loss: 0.3606 - val_acc: 0.9461
# Epoch 48/50
# 2896/2896 [==============================] - 9s - loss: 1.0998e-04 - acc: 1.0000 - val_loss: 0.3618 - val_acc: 0.9448
# Epoch 49/50
# 2896/2896 [==============================] - 9s - loss: 1.0154e-04 - acc: 1.0000 - val_loss: 0.3674 - val_acc: 0.9434
# Epoch 50/50
# 2896/2896 [==============================] - 9s - loss: 9.1682e-05 - acc: 1.0000 - val_loss: 0.3707 - val_acc: 0.9434

# %%
train_losses = history.history["loss"]
val_losses = history.history["val_loss"]
plt.plot([i for i in range(0,50)],train_losses,val_losses)
plt.legend(["Train Loss","Val Loss"])
plt.show()

# %%
#history.history
train_losses = history.history["acc"]
val_losses = history.history["val_acc"]
plt.plot([i for i in range(0,50)],train_losses,val_losses)
plt.legend(["Train_acc","Val_acc"])
plt.show()
