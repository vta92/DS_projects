# %%
from keras.datasets import imdb
import numpy as np

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)
# Out:
# ...
# 17285120/17464789 [============================>.] - ETA: 0s

# %%
np.max(train_data)
# Out:
# [1,
#  9995,
#  2,
#  7,
#  2208,
#  7335,
#  3135,
#  4173,
#  3783,
#  509,
#  1683,
#  4702,
#  2,
#  2,
#  6,
#  201,
#  7,
#  6415,
#  687,
#  2,
#  2,
#  7,
#  6387,
#  548,
#  139,
#  7583,
#  295,
#  34,
#  4485,
#  5302,
#  2,
#  2,
#  2,
#  7,
#  2,
#  2,
#  146,
#  24,
#  1017,
#  2282,
#  133,
#  21,
#  4,
#  1591,
#  3113,
#  786,
#  2,
#  16,
#  125,
#  4,
#  2,
#  9790,
#  2039,
#  137,
#  267,
#  2,
#  5,
#  2,
#  120,
#  2024,
#  980,
#  2,
#  1248,
#  5666,
#  727,
#  1405,
#  6879,
#  1060,
#  6442,
#  18,
#  2,
#  1461,
#  2,
#  1883,
#  445,
#  109,
#  5369,
#  3696,
#  33,
#  236,
#  786,
#  5580,
#  7994,
#  8,
#  2,
#  2,
#  103,
#  2,
#  98,
#  11,
#  2,
#  1461,
#  24,
#  66,
#  351,
#  1461,
#  165,
#  116,
#  17,
#  2545,
#  18,
#  6717,
#  8694,
#  5514,
#  980,
#  2545,
#  165,
#  734,
#  18,
#  2311,
#  52,
#  84,
#  157,
#  18,
#  7232,
#  11,
#  661,
#  8,
#  607,
#  3531,
#  223,
#  1066,
#  445,
#  9236,
#  996,
#  8,
#  2898,
#  4931,
#  8,
# ...

# %%
print(np.size(train_data[0]))
print(np.size(train_data))
#what does this mean? 218 words review for the first output. 25k reviews total in the second output.
#each word is mapped to an integer, up to 10000 unique words (based on usage).
# Out:
# 218
# 25000

# %%
print(np.size(train_data[2]))
# Out:
# 141

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# %%
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
np.max(x_train)
# Out:
# 1.0
