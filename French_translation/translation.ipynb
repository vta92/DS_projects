# %%
import os, sys

from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, GRU, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#On each line, the text file contains an English sentence and its French translation, separated by a tab.
f = open('fra.txt', encoding="utf-8")

# %%
#f.readlines()

# %%
def processing(total_lines=40000):
    '''
    Description:
        process 'fra.txt' file to output the lists of original sentences, 
        translated sentences, formated translated sentences for reinput
    Parameters:
        number of lines to be processed
    Return:
        3 list:
        original_sent: original sentences in list form from the 'fra.txt'
        translated_sent: translated sentences with "<eos>" token at the end
        reinput_sent: translated sences with "<sos>" token at the begining
    '''
    original_sent = list()
    translated_sent = list()
    reinput_sent = list()
    assert(total_lines > 0) and type(total_lines) == int, ValueError("input must be larger than 0, int datatype")
    try:
        with open('fra.txt',encoding='utf-8') as f:
            for i in range(total_lines):
                line = f.readline()
                if '\t' in line:
                    o_sent, t_sent, _ = line.rsplit('\t')
                    original_sent.append(o_sent)
                    translated_sent.append(t_sent+" <eos>") #end of sentence token
                    reinput_sent.append("<sos> "+t_sent) #start of sentence token
    except:
        raise ("number of lines not provided as parameter or 'fra.txt' doesn't exist")
    return original_sent, translated_sent, reinput_sent
            
original_sent, translated_sent,reinput_sent = processing(total_lines= 1)

# %% [markdown]
# LSTM encoder, LSTM decoder. Seq2Seq architecture

# %%
BATCH_SIZE = 64
EPOCHS = 20
LSTM_NODES =256
NUM_SENTENCES = 20000
MAX_SENTENCE_LENGTH = 50
MAX_NUM_WORDS = 20000
EMBEDDING_SIZE = 100

# %%
#input_sentences
#output_sentences
output_sentences_inputs
# Out:
# ['<sos> Va !',
#  '<sos> Salut !',
#  '<sos> Salut.',
#  '<sos> Cours\u202f!',
#  '<sos> Courez\u202f!',
#  '<sos> Qui ?',
#  '<sos> Ça alors\u202f!',
#  '<sos> Au feu !',
#  "<sos> À l'aide\u202f!",
#  '<sos> Saute.',
#  '<sos> Ça suffit\u202f!',
#  '<sos> Stop\u202f!',
#  '<sos> Arrête-toi !',
#  '<sos> Attends !',
#  '<sos> Attendez !',
#  '<sos> Poursuis.',
#  '<sos> Continuez.',
#  '<sos> Poursuivez.',
#  '<sos> Bonjour !',
#  '<sos> Salut !',
#  '<sos> Je comprends.',
#  "<sos> J'essaye.",
#  "<sos> J'ai gagné !",
#  "<sos> Je l'ai emporté !",
#  '<sos> J’ai gagné.',
#  '<sos> Oh non !',
#  '<sos> Attaque !',
#  '<sos> Attaquez !',
#  '<sos> Santé !',
#  '<sos> À votre santé !',
#  '<sos> Merci !',
#  '<sos> Tchin-tchin !',
#  '<sos> Lève-toi.',
#  '<sos> Va, maintenant.',
#  '<sos> Allez-y maintenant.',
#  '<sos> Vas-y maintenant.',
#  "<sos> J'ai pigé !",
#  '<sos> Compris !',
#  '<sos> Pigé\u202f?',
#  '<sos> Compris\u202f?',
#  "<sos> T'as capté\u202f?",
#  '<sos> Monte.',
#  '<sos> Montez.',
#  '<sos> Serre-moi dans tes bras !',
#  '<sos> Serrez-moi dans vos bras !',
#  '<sos> Je suis tombée.',
#  '<sos> Je suis tombé.',
#  '<sos> Je sais.',
#  '<sos> Je suis parti.',
#  '<sos> Je suis partie.',
#  "<sos> J'ai menti.",
#  "<sos> J'ai perdu.",
#  '<sos> J’ai payé.',
#  "<sos> J'ai 19 ans.",
#  '<sos> Je vais bien.',
#  '<sos> Ça va.',
#  '<sos> Écoutez !',
#  "<sos> C'est pas possible\u202f!",
#  '<sos> Impossible\u202f!',
#  '<sos> En aucun cas.',
#  '<sos> Sans façons\u202f!',
#  "<sos> C'est hors de question !",
#  "<sos> Il n'en est pas question !",
#  "<sos> C'est exclu !",
#  '<sos> En aucune manière !',
#  '<sos> Hors de question !',
#  '<sos> Vraiment\u202f?',
#  '<sos> Vrai ?',
#  '<sos> Ah bon ?',
#  '<sos> Merci !',
#  '<sos> On essaye.',
#  '<sos> Nous avons gagné.',
#  '<sos> Nous gagnâmes.',
#  "<sos> Nous l'avons emporté.",
#  "<sos> Nous l'emportâmes.",
#  '<sos> Demande à Tom.',
#  '<sos> Fantastique\u202f!',
#  '<sos> Sois calme !',
#  '<sos> Soyez calme !',
#  '<sos> Soyez calmes !',
#  '<sos> Sois détendu !',
#  '<sos> Sois juste !',
#  '<sos> Soyez juste !',
#  '<sos> Soyez justes !',
#  '<sos> Sois équitable !',
#  '<sos> Soyez équitable !',
#  '<sos> Soyez équitables !',
#  '<sos> Sois gentil.',
#  '<sos> Sois gentil !',
#  '<sos> Sois gentille !',
#  '<sos> Soyez gentil !',
#  '<sos> Soyez gentille !',
#  '<sos> Soyez gentils !',
#  '<sos> Soyez gentilles !',
#  '<sos> Dégage\u202f!',
#  '<sos> Appelle-moi !',
#  '<sos> Appellez-moi !',
#  '<sos> Appelle-nous !',
#  '<sos> Appelez-nous !',
#  '<sos> Entrez\u202f!',
#  '<sos> Entre.',
#  '<sos> Entre !',
#  '<sos> Entrez !',
#  '<sos> Allez\u202f!',
#  '<sos> Allez !',
#  '<sos> Viens\xa0!',
#  '<sos> Venez\u202f!',
#  '<sos> Laisse tomber !',
#  '<sos> Laissez tomber !',
#  '<sos> Laisse-le tomber !',
#  '<sos> Laissez-le tomber !',
#  '<sos> Va chercher Tom.',
#  '<sos> Sortez\u202f!',
#  '<sos> Sors !',
#  '<sos> Sortez !',
#  '<sos> Sors.',
#  '<sos> Casse-toi.',
#  '<sos> Dégage\u202f!',
#  '<sos> Pars !',
#  '<sos> Va te faire foutre !',
#  '<sos> Pars !',
#  '<sos> Dégage !',
#  '<sos> Fous le camp !',
#  "<sos> Pars d'ici.",
#  "<sos> Va t'en !",
#  '<sos> Disparais !',
#  '<sos> Allez-vous en !',
#  '<sos> Rentrez à la maison.',
#  '<sos> Rentre à la maison.',
#  '<sos> Rentre chez toi.',
#  '<sos> Rentrez chez vous.',
#  '<sos> Va doucement !',
#  '<sos> Allez doucement !',
#  '<sos> Adieu !',
#  '<sos> À la revoyure.',
#  '<sos> Attends un peu !',
#  '<sos> Attendez un peu !',
#  '<sos> Tiens bon !',
#  '<sos> Tenez bon !',
#  '<sos> Il laissa tomber.',
#  '<sos> Il a laissé tomber.',
#  '<sos> Il court.',
#  '<sos> Aide-moi !',
#  '<sos> Aide-moi.',
#  '<sos> Aidez-moi.',
#  '<sos> Aidez-nous !',
#  '<sos> Aide-nous !',
#  '<sos> Ne bouge plus !',
#  '<sos> Ne quittez pas.',
#  '<sos> Fais un câlin à Tom.',
#  '<sos> Je suis du même avis.',
#  "<sos> J'ai pleuré.",
#  '<sos> Je me suis assoupi.',
#  '<sos> Je me suis assoupie.',
#  '<sos> Je conduis.',
#  '<sos> Je fume.',
#  '<sos> Je ronfle.',
#  '<sos> Je pue.',
#  '<sos> Je me suis tenu debout.',
#  '<sos> Je me suis tenue debout.',
#  '<sos> J’ai promis.',
#  '<sos> J’ai juré.',
#  "<sos> J'essayai.",
#  "<sos> J'ai essayé.",
#  "<sos> J'ai tenté.",
#  '<sos> J’ai fait signe.',
#  "<sos> J'irai.",
#  '<sos> Je suis Tom.',
#  '<sos> Je suis gras.',
#  '<sos> Je suis gros.',
#  '<sos> Je suis en forme.',
#  '<sos> Je suis touché !',
#  '<sos> Je suis touchée !',
#  '<sos> Je suis malade.',
#  '<sos> Je suis triste.',
#  '<sos> Je suis timide.',
#  '<sos> Je suis mouillé.',
#  '<sos> Je suis mouillée.',
#  "<sos> C'est bibi\u202f!",
#  '<sos> Joignez-vous.',
#  '<sos> Joignez-vous à nous.',
#  '<sos> Garde-le !',
#  '<sos> Gardez-le !',
#  '<sos> Embrasse-moi.',
#  '<sos> Embrassez-moi.',
#  '<sos> Moi aussi.',
#  '<sos> Ouvre-moi\u202f!',
#  '<sos> Ouvre.',
#  '<sos> Parfait\u202f!',
#  '<sos> À plus tard !',
#  '<sos> À bientôt !',
#  '<sos> À la prochaine !',
#  '<sos> À plus.',
#  '<sos> Montre-moi !',
#  '<sos> Montrez-moi !',
#  '<sos> Taisez-vous\u202f!',
#  '<sos> Ferme-la\u202f!',
#  '<sos> Tais-toi !',
#  '<sos> Ferme-la !',
#  '<sos> La ferme !',
#  '<sos> Pas grave.',
#  '<sos> À plus tard !',
#  '<sos> Prends-le\u202f!',
#  '<sos> Prenez-le\u202f!',
#  '<sos> Prends-le !',
#  '<sos> Prenez-le !',
#  '<sos> Dis-moi !',
#  '<sos> Dites-moi !',
#  '<sos> Tom a gagné.',
#  '<sos> Réveille-toi\u202f!',
#  '<sos> Réveille-toi !',
#  '<sos> Réveillez-vous !',
#  '<sos> Réveille-toi !',
#  '<sos> Réveillez-vous !',
#  '<sos> Lave-toi !',
#  '<sos> Lavez-vous !',
#  '<sos> Nous savons.',
#  '<sos> Nous perdîmes.',
#  '<sos> Nous avons perdu.',
#  '<sos> Nous fûmes battus.',
#  '<sos> Nous fûmes battues.',
#  '<sos> Nous fûmes défaits.',
#  '<sos> Nous fûmes défaites.',
#  '<sos> Nous avons été défaits.',
#  '<sos> Nous avons été défaites.',
#  '<sos> Nous avons été battus.',
#  '<sos> Nous avons été battues.',
#  '<sos> Bienvenue\u202f!',
#  '<sos> Qui a gagné ?',
#  "<sos> Qui l'a emporté ?",
#  '<sos> Tu cours.',
#  '<sos> Suis-je gros ?',
#  '<sos> Suis-je grosse ?',
#  '<sos> Demande-leur.',
#  '<sos> Demandez-leur.',
#  '<sos> Recule\u2009!',
#  '<sos> Reculez.',
#  '<sos> Recule\u2009!',
#  '<sos> Reculez.',
#  '<sos> Retire-toi\u2009!',
#  '<sos> Retirez-vous.',
#  '<sos> Sois un homme !',
#  '<sos> Soyez un homme !',
#  '<sos> Sois calme !',
#  '<sos> Soyez calme !',
#  '<sos> Soyez calmes !',
#  '<sos> Aucune idée.',
#  "<sos> J'en sais foutre rien.",
#  '<sos> Appelle Tom.',
#  '<sos> Appelez Tom.',
#  '<sos> Courage\u202f!',
#  '<sos> Détends-toi\u202f!',
#  '<sos> Menottez-le.',
#  '<sos> Avance !',
#  '<sos> Avancez !',
#  '<sos> Continue à rouler !',
#  '<sos> Continuez à rouler !',
#  '<sos> Trouve Tom.',
#  '<sos> Trouvez Tom.',
#  '<sos> Réparez ceci.',
#  '<sos> Répare ça.',
#  '<sos> Lâche-toi !',
#  '<sos> Descends !',
#  '<sos> Descendez !',
#  '<sos> Lâche-toi !',
#  '<sos> Lâchez-vous !',
#  "<sos> Va voir ailleurs si j'y suis\u202f!",
#  '<sos> Dégage\u202f!',
#  '<sos> Va au diable !',
#  '<sos> Sois réaliste !',
#  '<sos> Passe devant !',
#  '<sos> Vas-y !',
#  '<sos> Avance !',
#  '<sos> Vas-y.',
#  '<sos> Poursuis !',
#  '<sos> Passe devant !',
#  '<sos> Vas-y !',
#  '<sos> Bien joué\u202f!',
#  '<sos> Bon boulot\u202f!',
#  '<sos> Beau travail\u202f!',
#  '<sos> Attrape-le.',
#  '<sos> Attrapez-le.',
#  '<sos> Amuse-toi bien !',
#  '<sos> Amusez-vous bien !',
#  '<sos> Il essaye.',
#  '<sos> Il est mouillé.',
#  '<sos> Aide Tom.',
#  '<sos> Aidez Tom.',
#  '<sos> Salut, les mecs !',
#  "<sos> Comme c'est mignon\u202f!",
#  '<sos> Quelle profondeur\u202f?',
#  "<sos> Comme c'est chouette !",
#  "<sos> Comme c'est gentil !",
#  "<sos> C'est du joli !",
#  "<sos> Comme c'est agréable !",
#  '<sos> Dépêche-toi.',
#  '<sos> Grouille\u202f!',
#  '<sos> Pressez-vous !',
#  '<sos> Fiça !',
#  "<sos> Je m'en suis bien sorti.",
#  "<sos> Je m'en suis bien sortie.",
#  "<sos> Je l'ai fait.",
#  "<sos> C'est moi qui l'ai fait.",
#  "<sos> J'ai échoué.",
#  "<sos> J'ai oublié.",
#  "<sos> J'ai compris.",
#  "<sos> J'ai compris.",
#  "<sos> J'ai capté.",
#  "<sos> J'ai aidé.",
#  "<sos> J'ai sauté.",
#  '<sos> J’ai regardé.',
#  '<sos> J’ai râlé.',
#  '<sos> J’ai fait signe de la tête.',
#  '<sos> J’ai obéi.',
#  '<sos> Je téléphonai.',
#  "<sos> J'ai téléphoné.",
#  '<sos> Je refuse.',
#  '<sos> Je le refuse.',
#  '<sos> Je me suis reposé.',
#  '<sos> Je me suis reposée.',
#  "<sos> Je l'ai vu.",
#  '<sos> Je l’ai vu.',
#  '<sos> J’ai soupiré.',
#  '<sos> Je suis resté.',
#  '<sos> Je suis restée.',
#  '<sos> J’ai parlé.',
#  "<sos> Je l'utilise.",
#  "<sos> J'en fais usage.",
#  "<sos> Je m'en sers.",
#  '<sos> Je paierai.',
#  '<sos> Je vais essayer.',
#  "<sos> J'essaierai.",
#  '<sos> Je suis revenu.',
#  '<sos> Me revoilà.',
#  '<sos> Je suis chauve.',
#  '<sos> Je suis occupé.',
#  '<sos> Je suis occupée.',
#  '<sos> Je suis calme.',
#  "<sos> J'ai froid.",
#  '<sos> Je suis détendu.',
#  '<sos> Je suis détendue.',
#  '<sos> Je suis sourd.',
#  '<sos> Je suis sourde.',
#  "<sos> J'en ai fini.",
#  '<sos> Je suis juste.',
#  "<sos> J'ai la peau claire.",
#  "<sos> J'ai le teint clair.",
#  '<sos> Je suis rapide.',
#  '<sos> Tout va bien.',
#  '<sos> Je vais bien.',
#  '<sos> Ça va.',
#  '<sos> Je suis libre !',
#  '<sos> Je suis libre.',
#  '<sos> Je suis disponible.',
#  '<sos> Je suis repu\u202f!',
#  '<sos> Je suis rassasié\u202f!',
#  "<sos> J'en suis.",
#  '<sos> Je suis de la partie.',
#  '<sos> Je suis content.',
#  '<sos> Je suis chez moi.',
#  '<sos> Je suis en retard.',
#  '<sos> Je suis paresseux.',
#  '<sos> Je suis fainéant.',
#  '<sos> Je suis paresseuse.',
#  '<sos> Je suis fainéante.',
#  '<sos> Je vais bien.',
#  '<sos> Je me porte bien.',
#  '<sos> Je suis riche.',
#  '<sos> Je suis en sécurité.',
#  '<sos> Je suis malade.',
#  "<sos> J'en suis certain.",
#  '<sos> Je suis certain.',
#  "<sos> J'en suis sûr.",
#  "<sos> J'en suis sûre.",
#  '<sos> Je suis grande.',
#  '<sos> Je suis mince.',
#  '<sos> Je suis ordonné.',
#  '<sos> Je suis ordonnée.',
#  '<sos> Je suis laid.',
#  '<sos> Je suis laide.',
#  '<sos> Je suis faible.',
#  '<sos> Je vais bien.',
#  '<sos> Je me porte bien.',
#  "<sos> J'ai gagné.",
#  "<sos> Je l'ai emporté.",
#  '<sos> Ça aide.',
#  '<sos> Ça fait mal.',
#  '<sos> Elle marche.',
#  '<sos> Ça fonctionne.',
#  "<sos> C'est Tom.",
#  "<sos> C'est marrant.",
#  "<sos> C'est rigolo.",
#  "<sos> C'est le sien.",
#  "<sos> C'est la sienne.",
#  "<sos> C'est nouveau.",
#  "<sos> C'est neuf.",
#  "<sos> C'est bizarre.",
#  '<sos> Il est rouge.',
#  '<sos> C’est triste.',
#  "<sos> Défense d'entrer.",
#  "<sos> N'entrez pas.",
#  '<sos> Embrasse Tom.',
#  '<sos> Laisse tomber !',
#  '<sos> Laissez tomber !',
#  '<sos> Laissez-moi !',
#  '<sos> Laisse-nous !',
#  '<sos> Laissez-nous !',
#  '<sos> Allons-y !',
#  '<sos> Allons-y !',
#  '<sos> Attention !',
#  '<sos> Regarde donc !',
#  '<sos> Épouse-moi !',
#  '<sos> Épousez-moi !',
#  '<sos> Puis-je partir ?',
#  '<sos> Puis-je y aller ?',
#  "<sos> Puis-je m'y rendre ?",
#  '<sos> Sauve Tom.',
#  '<sos> Sauvez Tom.',
#  '<sos> Elle est venue.',
#  '<sos> Elle est morte.',
#  '<sos> Elle court.',
#  '<sos> Assieds-toi !',
#  '<sos> Asseyez-vous !',
#  '<sos> Assieds-toi.',
#  '<sos> Assieds-toi ici.',
#  '<sos> Asseyez-vous ici.',
#  '<sos> Parle plus fort\u202f!',
#  '<sos> Parlez plus fort\u202f!',
#  '<sos> Lève-toi.',
#  '<sos> Arrête Tom.',
#  '<sos> Stoppez Tom.',
#  '<sos> Goûte-le.',
#  '<sos> Goûte-la.',
#  '<sos> Goûtez-le.',
#  '<sos> Goûtez-la.',
#  '<sos> Dis-le à Tom.',
#  '<sos> Informez-en Tom.',
#  '<sos> Génial\u202f!',
#  '<sos> Excellent\u202f!',
#  '<sos> Formidable !',
#  '<sos> Ils gagnèrent.',
#  '<sos> Elles gagnèrent.',
#  '<sos> Ils ont gagné.',
#  '<sos> Elles ont gagné.',
#  '<sos> Tom est venu.',
#  '<sos> Tom est mort.',
#  '<sos> Tom savait.',
#  '<sos> Tom est parti.',
#  '<sos> Tom partit.',
#  '<sos> Tom a menti.',
#  '<sos> Tom ment.',
#  '<sos> Tom a perdu.',
#  '<sos> Tom a payé.',
#  '<sos> Trop tard.',
#  '<sos> Faites-moi confiance.',
#  '<sos> Fais-moi confiance.',
#  '<sos> Fais un effort.',
#  '<sos> Essaies-en !',
#  '<sos> Essayez-en !',
#  '<sos> Essaie ceci !',
#  '<sos> Essayez ceci !',
#  '<sos> Utilise ceci.',
#  '<sos> Utilisez ceci.',
#  '<sos> Emploie ceci !',
#  '<sos> Employez ceci !',
#  '<sos> Avertis Tom.',
#  '<sos> Préviens Tom.',
#  '<sos> Regarde-moi !',
#  '<sos> Regardez-moi !',
#  '<sos> Regardez-nous !',
#  '<sos> Regarde-nous !',
#  "<sos> Nous sommes d'accord.",
#  '<sos> Nous irons.',
#  '<sos> Nous allons bien.',
#  '<sos> Pour quoi faire\u202f?',
#  '<sos> À quoi bon ?',
#  "<sos> Qu'est-ce qu'on s'est marrés !",
#  "<sos> Qu'est-ce qu'on s'est marrées !",
#  '<sos> Qui est venu ?',
#  '<sos> Qui est mort ?',
#  '<sos> Qui est tombé\xa0?',
#  '<sos> Qui démissionne ?',
#  '<sos> Qui est-il\u202f?',
#  '<sos> Écris-moi !',
#  '<sos> Écrivez-moi !',
#  '<sos> Tu as perdu.',
#  '<sos> Vous avez perdu.',
#  '<sos> Après vous.',
#  '<sos> En joue ! Feu !',
#  '<sos> Suis-je en retard ?',
#  '<sos> Répondez-moi.',
#  '<sos> Assieds-toi !',
#  '<sos> Asseyez-vous !',
#  '<sos> Les oiseaux volent.',
#  '<sos> À tes souhaits\u202f!',
#  '<sos> Appelle à la maison !',
#  '<sos> Calmez-vous !',
#  '<sos> Calme-toi.',
#  '<sos> Pouvons-nous partir ?',
#  '<sos> Pouvons-nous nous en aller ?',
#  '<sos> Pouvons-nous y aller ?',
#  '<sos> Attrape Tom.',
#  '<sos> Attrapez Tom.',
#  '<sos> Rattrape-le.',
#  '<sos> Calme-toi.',
#  '<sos> Reviens !',
#  '<sos> Revenez !',
#  '<sos> Viens ici.',
#  '<sos> Venez là.',
#  '<sos> Viens\xa0!',
#  '<sos> Venez\u202f!',
#  '<sos> Venez ici !',
#  '<sos> Viens chez nous !',
#  '<sos> Venez chez nous !',
#  '<sos> Viens chez moi !',
#  '<sos> Venez chez moi !',
#  '<sos> Viens bientôt !',
#  '<sos> Venez bientôt !',
#  '<sos> Calmez-vous !',
#  '<sos> Ai-je gagné ?',
#  "<sos> L'ai-je emporté ?",
#  '<sos> Est-ce moi qui ai gagné ?',
#  '<sos> Faites-le maintenant.',
#  '<sos> Des chiens aboient.',
#  '<sos> Les chiens aboient.',
#  '<sos> Ne demande pas !',
#  '<sos> Ne pleure pas !',
#  '<sos> Ne meurs pas !',
#  '<sos> Ne mourez pas !',
#  '<sos> Ne mens pas.',
#  '<sos> Ne courez pas.',
#  '<sos> Ne cours pas.',
#  '<sos> Excuse-moi.',
#  '<sos> Excusez-moi.',
#  '<sos> Pardon\u202f?',
#  '<sos> Je vous demande pardon\u202f?',
#  '<sos> Plaît-il\u202f?',
#  '<sos> Plait-il\u202f?',
#  '<sos> Pardon ?',
#  '<sos> Fantastique\u202f!',
#  '<sos> Sens ça !',
#  '<sos> Sentez ça !',
#  '<sos> Touche ça !',
#  '<sos> Touchez ça !',
#  '<sos> Suis-moi.',
#  '<sos> Suis-nous !',
#  '<sos> Suivez-nous !',
#  '<sos> Oublie !',
#  '<sos> Oublie-le !',
#  '<sos> Oubliez !',
#  '<sos> Oubliez-le !',
#  '<sos> Laisse tomber.',
#  '<sos> Oublie.',
#  '<sos> Oublie-le !',
#  '<sos> Trouve un emploi !',
#  '<sos> Trouve un boulot !',
#  '<sos> Trouvez un emploi !',
#  '<sos> Trouvez un boulot !',
#  '<sos> Prépare-toi.',
#  '<sos> Préparez-vous.',
#  '<sos> Va le chercher !',
#  '<sos> Allez le chercher !',
#  '<sos> Entrez\u202f!',
#  '<sos> Va au lit !',
#  '<sos> Allez au lit !',
#  '<sos> Bonne chance\u202f!',
#  '<sos> Bonne chance.',
#  '<sos> Attrape ça !',
#  '<sos> Attrapez ça !',
#  '<sos> Saisis-toi de ça !',
#  '<sos> Saisissez-vous de ça !',
#  '<sos> Attrape ça !',
#  '<sos> Attrapez ça !',
#  '<sos> Pas touche\u202f!',
#  '<sos> Il est malade.',
#  '<sos> Il est vieux.',
#  '<sos> Il est DJ.',
#  '<sos> Il est bon.',
#  '<sos> Il est paresseux.',
#  '<sos> Il est à moi.',
#  '<sos> Il est riche.',
#  '<sos> Il est sexy.',
#  '<sos> Me voici.',
#  '<sos> Voilà cinq dollars.',
#  '<sos> Halte au feu !',
#  '<sos> Cessez le feu !',
#  '<sos> Tiens ça !',
#  '<sos> Tenez ça !',
#  '<sos> Tenez ceci !',
#  '<sos> Tiens ceci !',
#  "<sos> C'est affreux\u202f!",
#  "<sos> Comme c'est bizarre !",
#  '<sos> Comment Tom va-t-il ?',
#  '<sos> Comment va Tom ?',
#  "<sos> J'ai froid.",
#  '<sos> Je suis bon.',
#  '<sos> Je vais bien.',
#  '<sos> Je suis malade.',
#  '<sos> Je suis sûr.',
#  '<sos> Je suis certain.',
#  '<sos> Je vous en prie.',
#  '<sos> Je vous en conjure.',
#  '<sos> Je vous en supplie.',
#  '<sos> Je te prie.',
#  '<sos> Je sais courir.',
#  '<sos> Je sais skier.',
#  "<sos> J'eus un mouvement de recul.",
#  "<sos> J'ai eu un mouvement de recul.",
#  '<sos> Je suis rentré en moi-même.',
#  '<sos> J’ai expiré.',
#  "<sos> J'ai abandonné.",
#  '<sos> Je donne ma langue au chat.',
#  "<sos> J'abandonne.",
#  '<sos> Je me suis mis à avoir chaud.',
#  '<sos> Je me suis mise à avoir chaud.',
#  '<sos> Je me suis amusé.',
#  '<sos> Je me suis amusée.',
#  '<sos> Je me suis marré.',
#  '<sos> Je me suis marrée.',
#  '<sos> Je déteste ça.',
#  "<sos> Je l'ai.",
#  "<sos> J'ai frappé Tom.",
#  "<sos> J'espère bien.",
#  '<sos> Je me suis dépêché.',
#  '<sos> Je me suis dépêchée.',
#  '<sos> J’ai inspiré.',
#  '<sos> Je le savais.',
#  "<sos> J'aime ça.",
#  '<sos> Je l’ai perdu.',
#  "<sos> J'adore ça !",
#  "<sos> J'adore ça !",
#  '<sos> Je suis sérieux\u202f!',
#  '<sos> Je suis sérieux.',
#  '<sos> Je dois y aller.',
#  "<sos> Il faut que j'y aille.",
#  '<sos> Il me faut y aller.',
#  '<sos> Il me faut partir.',
#  "<sos> Il me faut m'en aller.",
#  '<sos> Je dois partir.',
#  "<sos> Je dois m'en aller.",
#  "<sos> Il faut que je m'en aille.",
#  "<sos> J'en ai besoin.",
#  '<sos> Il me le faut.',
#  "<sos> J'ai remarqué.",
#  "<sos> J'ai payé d'avance.",
#  '<sos> Je le promets.',
#  '<sos> Je me suis détendu.',
#  '<sos> Je me suis détendue.',
#  "<sos> J'ai pris ma retraite.",
#  "<sos> J'ai dit non.",
#  "<sos> Je l'ai dit.",
#  "<sos> Je l'ai vu.",
#  '<sos> Je l’ai vu.',
#  '<sos> Je le vis.',
#  "<sos> J'en ai vu une.",
#  "<sos> J'en ai vu un.",
#  '<sos> Je vous vis.',
#  '<sos> Je te vis.',
#  "<sos> Je t'ai vue.",
#  "<sos> Je t'ai vu.",
#  '<sos> Je vous ai vues.',
#  '<sos> Je vous ai vus.',
#  '<sos> Je vous ai vue.',
#  '<sos> Je vous ai vu.',
#  '<sos> Je vois Tom.',
#  "<sos> J'ai crié.",
#  "<sos> J'ai trébuché.",
#  "<sos> J'ai plané.",
#  '<sos> Je le veux.',
#  "<sos> J'étais nouveau.",
#  "<sos> J'étais nouvelle.",
#  "<sos> J'irai.",
#  '<sos> Je me suis réveillé.',
#  '<sos> Je me suis éveillé.',
#  "<sos> Je serais d'accord.",
#  '<sos> Je partirais.',
#  "<sos> J'appellerai.",
#  '<sos> Je cuisinerai.',
#  "<sos> J'aiderai.",
#  '<sos> Je vivrai.',
#  "<sos> J'obéirai.",
#  '<sos> Je ferai mon sac.',
#  '<sos> Je ferai ma valise.',
#  '<sos> Je plierai mes gaules.',
#  '<sos> Je passerai.',
#  "<sos> J'abandonnerai.",
#  '<sos> Je chanterai.',
#  "<sos> J'arrêterai.",
#  '<sos> Je nagerai.',
#  '<sos> Je parlerai.',
#  '<sos> Je vais parler.',
#  "<sos> J'attendrai.",
#  '<sos> Je marcherai.',
#  '<sos> Je vais travailler.',
#  '<sos> Je travaillerai.',
#  '<sos> Je suis flic.',
#  '<sos> Je suis un homme.',
#  '<sos> Je suis en vie.',
#  '<sos> Je suis vivant.',
#  '<sos> Je suis vivante.',
#  '<sos> Je suis seule.',
#  '<sos> Je suis seul.',
#  '<sos> Je suis énervé.',
#  '<sos> Je suis en colère.',
#  '<sos> Je suis armé.',
#  '<sos> Je suis armée.',
#  '<sos> Je suis réveillé.',
#  '<sos> Je suis aveugle.',
#  '<sos> Je suis fauché.',
#  "<sos> J'ai décroché.",
#  '<sos> Je suis propre.',
#  '<sos> Je suis fou.',
#  '<sos> Je suis folle.',
#  '<sos> Je suis guéri.',
#  '<sos> Je suis guérie.',
#  "<sos> J'ai la tête qui tourne.",
#  '<sos> Je suis saoul.',
#  '<sos> Je suis soûl.',
#  '<sos> Je suis ivre.',
#  '<sos> Je me meurs.',
#  '<sos> Je suis en avance.',
#  '<sos> Je suis en premier.',
#  '<sos> Je suis difficile.',
#  '<sos> Je suis tatillon.',
#  '<sos> Je suis tatillonne.',
#  '<sos> Je pars maintenant.',
#  '<sos> Je me tire.',
#  '<sos> J’y vais.',
#  '<sos> Je pars.',
#  '<sos> Je suis loyal.',
#  '<sos> Je suis loyale.',
#  '<sos> Je suis veinard.',
#  '<sos> Je suis veinarde.',
#  "<sos> J'ai du pot.",
#  '<sos> Je suis chanceux.',
#  '<sos> Je suis chanceuse.',
#  '<sos> Je suis en train de mentir.',
#  '<sos> Je suis nu.',
#  '<sos> Je suis nue.',
#  '<sos> Je me trouve nu.',
#  '<sos> Je me trouve nue.',
#  '<sos> Je suis à poil.',
#  '<sos> Je suis tranquille.',
#  '<sos> Je suis prête !',
#  '<sos> Je suis prêt !',
#  '<sos> Je suis prêt.',
#  "<sos> J'ai raison.",
#  '<sos> Je suis sobre.',
#  '<sos> Excuse-moi.',
#  '<sos> Désolé.',
#  '<sos> Excusez-moi.',
#  '<sos> Désolé !',
#  '<sos> Je suis désolé.',
#  '<sos> Je suis désolée.',
#  '<sos> Je suis coincée.',
#  '<sos> Je suis timide.',
#  '<sos> Je suis fatigué !',
#  '<sos> Je suis dur.',
#  '<sos> Je suis dure.',
#  '<sos> Je suis dur à cuire.',
#  '<sos> Je suis dure à cuire.',
#  '<sos> Je suis à toi.',
#  '<sos> Je suis à vous.',
#  "<sos> J'ai perdu.",
#  '<sos> Est-ce que Tom va bien ?',
#  '<sos> Tom va-t-il bien ?',
#  "<sos> C'est grave\u202f?",
#  '<sos> Est-ce éloigné ?',
#  '<sos> Est-ce loin ?',
#  '<sos> Est-ce chaud\xa0?',
#  '<sos> Est-ce toi ?',
#  '<sos> Est-ce vous ?',
#  "<sos> Est-ce que c'est vous ?",
#  '<sos> Ça a échoué.',
#  "<sos> C'est nouveau.",
#  "<sos> C'est neuf.",
#  '<sos> Il a neigé.',
#  '<sos> Ça sent mauvais.',
#  '<sos> Ça pue.',
#  "<sos> C'était bon.",
#  "<sos> C'était correct.",
#  "<sos> C'était OK.",
#  '<sos> Ça a fonctionné.',
#  '<sos> Ça a marché.',
#  '<sos> Il est trois heures et demie.',
#  '<sos> Il est huit heures trente.',
#  '<sos> Il est 8\xa0h\xa030.',
#  "<sos> C'est une télé.",
#  '<sos> Il fait froid.',
#  "<sos> C'est froid.",
#  "<sos> C'est sombre.",
#  '<sos> Elle est morte.',
#  "<sos> C'est mort.",
#  '<sos> Il est mort.',
#  "<sos> C'est fait.",
#  "<sos> C'est simple.",
#  "<sos> C'est de la nourriture.",
#  "<sos> C'est gratuit.",
#  '<sos> Elle est ici.',
#  "<sos> C'est ici.",
#  "<sos> C'est le sien.",
#  "<sos> C'est la sienne.",
#  '<sos> Il est tard.',
#  "<sos> C'est perdu.",
#  "<sos> C'est le mien.",
#  "<sos> C'est la mienne.",
#  "<sos> C'est à moi.",
#  "<sos> Il s'agit du mien.",
#  "<sos> C'est ouvert.",
#  "<sos> C'est le nôtre.",
#  "<sos> C'est la nôtre.",
#  "<sos> C'est à nous.",
#  "<sos> C'est du sable.",
#  '<sos> Il est temps !',
#  "<sos> C'est l'heure.",
#  "<sos> C'est vrai\u202f!",
#  "<sos> C'est du boulot.",
#  '<sos> Restez calme.',
#  '<sos> Garde ça.',
#  '<sos> Gardez cela.',
#  '<sos> Garde ça.',
#  '<sos> Gardez ceci.',
#  '<sos> Ainsi soit-il.',
#  '<sos> Laisse faire.',
#  '<sos> Laisse-moi partir\u202f!',
#  '<sos> Laissez-moi partir\u202f!',
#  '<sos> Lâche-moi\u202f!',
#  '<sos> Lâchez-moi\u202f!',
#  "<sos> Laisse-moi m'en aller !",
#  "<sos> Laissez-moi m'en aller !",
#  '<sos> Laissez-moi y aller !',
#  '<sos> Laisse-moi y aller !',
#  '<sos> Laisse-moi partir\u202f!',
#  '<sos> Laissez-moi partir\u202f!',
#  "<sos> Laisse-moi m'en aller !",
#  "<sos> Laissez-moi m'en aller !",
#  '<sos> Laissez-moi rentrer.',
#  '<sos> Laissez-moi entrer.',
#  '<sos> Demandons.',
#  '<sos> Mangeons.',
#  '<sos> Voyons voir !',
#  '<sos> Reste allongé, immobile !',
#  '<sos> Reste allongée, immobile !',
#  '<sos> Restez allongé, immobile !',
#  '<sos> Restez allongée, immobile !',
#  '<sos> Restez allongés, immobiles !',
#  '<sos> Restez allongées, immobiles !',
#  '<sos> Détourne le regard.',
#  '<sos> Regardez ailleurs.',
#  '<sos> Regarde derrière toi\u202f!',
#  '<sos> Regarde derrière\u202f!',
#  '<sos> Regarde ici.',
#  '<sos> Regardez ici.',
#  '<sos> Échauffe-toi !',
#  '<sos> Échauffez-vous !',
#  '<sos> Détends-toi !',
#  '<sos> Laisse-toi aller !',
#  '<sos> Laissez-vous aller !',
#  '<sos> Bouge de là.',
#  '<sos> Poussez-vous.',
#  '<sos> Pousse-toi.',
#  '<sos> Joli coup !',
#  '<sos> Pour sûr.',
#  '<sos> Mais ouais !',
#  '<sos> Pardi !',
#  '<sos> Bien sûr.',
#  '<sos> Pour sûr.',
#  '<sos> Je vous en prie !',
#  "<sos> Je t'en prie !",
#  '<sos> Pardon\u202f?',
#  '<sos> Je vous demande pardon\u202f?',
#  '<sos> Plaît-il\u202f?',
#  '<sos> Lis ceci.',
#  '<sos> Dis bonjour.',
#  '<sos> Voyez ci-dessus.',
#  '<sos> Voyez ci-dessous.',
#  '<sos> Voir ci-dessous.',
#  '<sos> Capturez-le\xa0!',
#  '<sos> Attrapez-le\xa0!',
#  '<sos> Vraiment\u202f?',
#  '<sos> Est-ce sérieux\u202f?',
#  '<sos> Sérieusement ?',
#  '<sos> Elle pleurait.',
#  '<sos> Elle pleura.',
#  '<sos> Elle a essayé.',
#  '<sos> Elle marche.',
#  '<sos> Elle est chaude.',
#  '<sos> Elle est très attirante.',
#  '<sos> Signe ici.',
#  '<sos> Signez ici.',
#  '<sos> Signe ça.',
#  '<sos> Signez ceci.',
#  '<sos> Ralentis !',
#  '<sos> Ralentissez !',
#  "<sos> Reste à l'écart.",
#  "<sos> Restez à l'écart.",
#  '<sos> Reste en arrière !',
#  '<sos> Restez en arrière !',
#  '<sos> Restez calme.',
#  '<sos> Reste calme.',
#  '<sos> Garde ton calme.',
#  '<sos> Garde ton sang-froid.',
#  '<sos> Reste tranquille.',
#  '<sos> Reste baissé.',
#  '<sos> Restez baissé.',
#  '<sos> Reste baissé.',
#  '<sos> Restez baissé.',
#  '<sos> Restez là !',
#  '<sos> Reste ici !',
#  '<sos> Restez ici.',
#  '<sos> Reste mince !',
#  '<sos> Recule\u2009!',
#  '<sos> Reculez\u2009!',
#  '<sos> Arrêtez !',
#  '<sos> Arrête ça\u202f!',
#  '<sos> Arrêtez ça !',
#  '<sos> Arrête ça !',
#  '<sos> Arrêtez-les.',
#  '<sos> Prends soin de toi !',
#  '<sos> Soyez prudente !',
#  '<sos> Prends soin de toi.',
#  '<sos> Prenez soin de vous.',
#  '<sos> Prends le mien.',
#  '<sos> Prends la mienne.',
#  '<sos> Prenez le mien.',
#  '<sos> Prenez la mienne.',
#  '<sos> Prends les miens.',
#  '<sos> Prends les miennes.',
#  '<sos> Prenez les miens.',
#  '<sos> Prenez les miennes.',
#  '<sos> Prends ça.',
#  '<sos> Prenez ça.',
#  '<sos> Merci !',
#  '<sos> Merci.',
#  "<sos> Il n'y a pas de problème.",
#  '<sos> Pas de problème.',
#  "<sos> Ce n'est pas grave.",
#  '<sos> Ça va.',
#  "<sos> C'est ça.",
#  '<sos> Et alors ?',
#  '<sos> Ils sont tombés.',
#  '<sos> Elles sont tombées.',
#  '<sos> Ils sont partis.',
#  '<sos> Elles sont parties.',
#  '<sos> Ils ont menti.',
#  '<sos> Elles ont menti.',
#  '<sos> Ils ont perdu.',
#  '<sos> Elles ont perdu.',
#  '<sos> Ils nageaient.',
#  '<sos> Elles nageaient.',
#  '<sos> Ils nagèrent.',
#  '<sos> Elles nagèrent.',
#  '<sos> Le temps est écoulé.',
#  '<sos> Tom cuisine.',
#  '<sos> Tom pleura.',
#  '<sos> Tom va bien.',
#  '<sos> Tom tricote.',
#  '<sos> Tom sait.',
#  '<sos> Tom assure.',
#  '<sos> Tom a parlé.',
#  '<sos> Tom a fait signe de la main.',
#  '<sos> Tom est en train de travailler.',
#  '<sos> Tom est gros.',
#  '<sos> Tom est en colère.',
#  '<sos> Tom est fou.',
#  '<sos> Tom est triste.',
#  '<sos> Fais confiance à Tom.',
#  '<sos> Faites confiance à Tom.',
#  '<sos> Essaie encore.',
#  '<sos> Essayez de nouveau.',
#  '<sos> Essaie de nouveau.',
#  '<sos> Essaie-le\u2009!',
#  '<sos> Tourne à gauche.',
#  '<sos> Attends ici.',
#  '<sos> Attends là.',
#  '<sos> Attendez ici.',
#  '<sos> Attendez là.',
#  '<sos> Attention !',
#  '<sos> Faites attention\u202f!',
#  '<sos> Fais attention\u202f!',
#  "<sos> Nous sommes tombés d'accord.",
#  '<sos> Nous avons réussi\u202f!',
#  '<sos> Nous avons réussi\u202f!',
#  "<sos> Nous l'avons fait.",
#  '<sos> Nous avons oublié.',
#  "<sos> Nous l'avons vu.",
#  "<sos> Nous l'avons vue.",
#  '<sos> Nous avons souri.',
#  '<sos> Nous discutâmes.',
#  '<sos> Nous avons discuté.',
#  '<sos> Nous nous sommes entretenus.',
#  '<sos> Nous nous sommes entretenues.',
#  '<sos> Nous nous entretînmes.',
#  '<sos> Nous attendîmes.',
#  '<sos> Nous avons attendu.',
#  '<sos> Nous sommes allés à pied.',
#  '<sos> Nous sommes allées à pied.',
#  '<sos> Nous essayerons.',
#  '<sos> Nous tenterons.',
#  "<sos> Nous l'emporterons.",
#  ...]
